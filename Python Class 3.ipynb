# %%
#String
name = "Mahaz"
print(f"name is {name}")
# Out:
# name is Mahaz

# %%
name = str(input("User's Name : "))
age = int(input("User's Age : "))
age_in10Years = age+10
print(f"{name} is {age} years old and in 10 Years he will be {age_in10Years} years old")
# Out:
# User's Name :  Aslam
# User's Age :  50
# Aslam is 50 years old and in 10 Years he will be 60 years old

# %%
#indexing & Slicing
a = "Python"
print(a[1])
# Out:
# y

# %%
print(a[-1])
# Out:
# n

# %%
a
# Out:
# 'Python'

# %%
a[4]
# Out:
# 'o'

# %%
len(a)
# Out:
# 6

# %%
a[2:5]
# Out:
# 'tho'

# %%
a[:]
# Out:
# 'Python'

# %%
a[::2]
# Out:
# 'Pto'

# %%
a[::-1]
# Out:
# 'nohtyP'

# %%
name = "Mahaz"
name[-5:-3]
# Out:
# 'Ma'

# %%
name = "Mujtaba"
name[-7:-4]
# Out:
# 'Muj'
